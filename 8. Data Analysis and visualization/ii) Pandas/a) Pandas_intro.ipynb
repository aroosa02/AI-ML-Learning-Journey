# %% [markdown]
# # Pandas  --- data manipulation lib
# Pandas is one of the most important Python libraries for data work, and once it clicks, it feels very powerful.
#
#  What is Pandas?
#
# pandas is a Python library used to:
#
# * handle tables (like Excel sheets)
# * clean data
# * analyze data
# * filter, sort, group, and transform data easily
#
#            “Excel + Python = Pandas”
#
#
# * ## Series
#   1d-array (object)
#
# * ## DataFrame
#   2d-array (heterogeneous tabular data structure)

# %%
import pandas as pd
