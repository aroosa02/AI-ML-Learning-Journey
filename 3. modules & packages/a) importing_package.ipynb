# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt, pi
print(sqrt(25))
print(pi)
# Out:
# 5.0
# 3.141592653589793

# %%
import numpy as np # np is an alias for numpy
np.array([1, 2, 3, 4, 5])
# Out:
# array([1, 2, 3, 4, 5])

# %%
from math import *
print(sin(pi / 2))
# Out:
# 1.0

# %%
from package.maths import addition
addition(5, 10)
# Out:
# 15

# %%
from package import maths
print(maths.addition(5, 10))
# Out:
# 15

# %%
import math

# GCD of two numbers
num1 = 48
num2 = 18
gcd_result = math.gcd(num1, num2)
print("GCD:", gcd_result)

# Factorial of a number
number = 5
factorial_result = math.factorial(number)
print("Factorial:", factorial_result)
# Out:
# GCD: 6
# Factorial: 120

# %%
try:
    import aroosa_file # This will raise an ImportError since the module doesn't exist
except ImportError as e:
    print("Import failed!")
    print("Error details:", e)
# Out:
# Import failed!
# Error details: No module named 'aroosa_file'
